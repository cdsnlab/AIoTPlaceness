# %%
import pandas as pd

# %%
df = pd.read_json('label_df.json')

# %%
df
# Out:
#          shortcode  category  \
# 0       nSnjwRPkcy         0
# 1      BB9zWt5wDn4         0
# 2       __1E4jsIvl         1
# 3      BdydHmshWOM         0
# 4      BV02kVwhEOw         2
# ...            ...       ...
# 16243  BWZZ8ehlsWE         0
# 16244  BYhA4CBBT2Y         4
# 16245  BNRfgzxjraZ         1
# 16246  BTowOUjlGB-         1
# 16247  BCp6MTOvF1a         5
#
#                                                image_src  \
# 0      /mnt/SEOUL_SUBWAY_DATA/20.Seolleung/249582208/...
# 1      /mnt/SEOUL_SUBWAY_DATA/06.Sindang/301080661/12...
# 2      /mnt/SEOUL_SUBWAY_DATA/08.Wangsimni/148519/138...
# 3      /mnt/SEOUL_SUBWAY_DATA/21.Yeoksam/800778814/26...
# 4      /mnt/SEOUL_SUBWAY_DATA/22.Gangnam/214082506/19...
# ...                                                  ...
# 16243  /mnt/SEOUL_SUBWAY_DATA/16.Jamsil/398307852/199...
# 16244  /mnt/SEOUL_SUBWAY_DATA/22.Gangnam/214082506/21...
# 16245  /mnt/SEOUL_SUBWAY_DATA/16.Jamsil/445344873/150...
# ...

# %%
df = pd.read_csv('100000_plus_labeled_scaled_pca_normalized_image_encoded_instagram.csv')

# %%
df
# Out:
#          Unnamed: 0       PC0       PC1       PC2       PC3       PC4  \
# 0       BjHHpIlAwm1 -1.069992  1.829028  0.265675  2.056675 -0.454587
# 1       BS2UjOhBPIi  0.433969 -0.208599  0.308072 -0.881441 -0.987364
# 2       BdJQhyqhC_i -0.954964  0.180683  2.614454  0.610347  1.043200
# 3       BZEAehRn-IP -0.260672 -1.194505  1.399101 -0.566905  0.140985
# 4       BnER2R_FjjQ  1.906564  0.718775  0.099959 -0.053707  0.790034
# ...             ...       ...       ...       ...       ...       ...
# 116243  BWZZ8ehlsWE  1.562990 -0.116110 -0.088992 -0.865709  0.599433
# 116244  BYhA4CBBT2Y -0.614773 -2.389856 -2.281784  0.212486  1.408443
# 116245  BNRfgzxjraZ -0.492432 -0.219701 -0.746674  1.303581  0.352026
# 116246  BTowOUjlGB- -0.294960 -0.461168  1.733641 -0.598459  0.221958
# 116247  BCp6MTOvF1a -0.445689  0.417949 -0.459621  0.704533 -0.416495
#
#              PC5       PC6       PC7       PC8  ...     PC290     PC291  \
# ...

# %%
df = pd.read_csv('100000_plus_labeled_scaled_text_doc2vec_instagram.csv')
df
# Out:
#          Unnamed: 0         0         1         2         3         4  \
# 0       BjHHpIlAwm1 -0.589064 -0.748003  0.571666 -0.104085  0.662687
# 1       BS2UjOhBPIi  1.024480  1.422865 -1.186952 -1.807672 -0.532177
# 2       BdJQhyqhC_i  0.198569 -0.065062  0.641731  0.391063 -0.212630
# 3       BZEAehRn-IP  0.435292  0.094398  0.422190  0.164513 -0.504567
# 4       BnER2R_FjjQ -0.594004 -2.018131  0.982516  0.718806  1.103013
# ...             ...       ...       ...       ...       ...       ...
# 116243  BWZZ8ehlsWE  0.054606 -0.231827  0.774089 -0.635296  0.392022
# 116244  BYhA4CBBT2Y  0.273095 -0.379808  0.658794  0.239229 -0.277202
# 116245  BNRfgzxjraZ -0.364276  1.645155 -2.277741 -0.371764  1.373532
# 116246  BTowOUjlGB-  0.338098  0.141998  0.505220 -0.549247  1.422680
# 116247  BCp6MTOvF1a -2.103146  1.056891 -1.404121  0.628000 -0.995364
#
#                5         6         7         8  ...       290       291  \
# ...
